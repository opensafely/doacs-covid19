# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../output/measure_doacs_with_weight_recorded.csv", usecols=["date", "weight_recorded", "on_doac"])
df['test']=df['weight_recorded']
df
# Out:
#    weight_recorded  on_doac        date  test
# 0                0   1594.0  2021-01-01     0
# 1                1    406.0  2021-01-01     1
# 2                0   1601.0  2021-02-01     0
# 3                1    399.0  2021-02-01     1
# 4                0   1602.0  2021-03-01     0
# 5                1    398.0  2021-03-01     1
# 6                0   1602.0  2021-04-01     0
# 7                1    398.0  2021-04-01     1

# %%
# carer
df=pd.read_csv("../output/measure_doacs_with_weight_recorded.csv", usecols=["date", "weight_recorded", "on_doac"])
pivot_df = df.pivot(index='date', columns='weight_recorded', values='on_doac')
pivot_df
#pivot_df.plot.bar(xlabel='Period', ylabel='Count', title='Proportion of patients prescribed a DOAC with a weight recorded in the last 12 months', stacked='True', edgecolor='black') 
#plt.legend(["On doac, weight not recorded in last 12 months", "On doac, weight recorded in last 12 months"], loc='lower center')
#axes = plt.gca()
#axes.spines['right'].set_visible(False)
#axes.spines['left'].set_visible(True)
#axes.spines['top'].set_visible(False)
#axes.spines['bottom'].set_visible(True)
#axes.yaxis.grid(color='grey', linestyle='dashed')
# Out:
# weight_recorded       0      1
# date
# 2021-01-01       1594.0  406.0
# 2021-02-01       1601.0  399.0
# 2021-03-01       1602.0  398.0
# 2021-04-01       1602.0  398.0
