# %%
import pandas as pd

# %%
df=pd.read_csv("../output/measure_doacs_by_sex.csv", usecols=["date", "sex", "on_doac", "population"])
sex=df["sex"]
female_subset=df.loc[df["sex"] == "F", :]
female_subset.plot(x="date", y="on_doac", title="Number of females on DOAC by month")
# Out:
# <AxesSubplot:title={'center':'Number of females on DOAC by month'}, xlabel='date'>
