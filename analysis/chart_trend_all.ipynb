# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../output/measure_doacs_by_sex.csv", usecols=["date", "sex", "on_doac", "population"])
df["date"] = pd.to_datetime(df["date"])
#sex=df["sex"]
#female_subset=df.loc[df["sex"] == "F", :]
df.plot(x="date", y="on_doac", title="Number of patients on DOAC by month")
# Out:
# <AxesSubplot:title={'center':'Number of patients on DOAC by month'}, xlabel='date'>
